# %% [markdown]
# # System Transformation

# %% [markdown]
# This notebook uses generated .csv files (buses, generators, links, loads, storage_units) as input and run optimization using Gurobi solver. Note: the input files are being read from '1c-LOPF' folder, where generated .csv files by data reader writer notebooks (from PyPSA-GB-H2\data...) are placed.

# %%
import os
from dotenv import find_dotenv, load_dotenv

load_dotenv(find_dotenv())
src_path = os.environ.get('PROJECT_SRC')
os.chdir(src_path)
os.getcwd()
# Out:
# 'C:\\Users\\ls1524\\Desktop\\PyPSA-GB-H2\\notebooks'

# %%
import pypsa
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 22})
plt.style.use('ggplot')
import pandas as pd
import cartopy.crs as ccrs

# %%
# import csv files

network = pypsa.Network()
network.import_from_csv_folder('1c-LOPF')
# Out:
# WARNING:pypsa.io:Importing network from PyPSA version v? while current version is v0.23.0. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.components:Applying weightings to all columns of `snapshot_weightings`
# INFO:pypsa.io:Imported network 1c-LOPF has buses, generators, links, loads, storage_units

# %%
# running the optimisation

network.lopf(network.snapshots, solver_name="gurobi", pyomo=False)
# Out:
# INFO:pypsa.linopf:Prepare linear problem
# INFO:pypsa.linopf:Total preparation time: 5.12s
# INFO:pypsa.linopf:Solve linear problem using Gurobi solver
# Set parameter Username
# Set parameter LicenseID to value 2682142
# Academic license - for non-commercial use only - expires 2026-06-25
# Read LP format model from file C:\Users\ls1524\AppData\Local\Temp\pypsa-problem-7hjuxxe4.lp
# Reading time = 2.66 seconds
# obj: 1752000 rows, 788419 columns, 2917080 nonzeros
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-1345U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1752000 rows, 788419 columns and 2917080 nonzeros
# Model fingerprint: 0x77a2ce59
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e-01, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 1743240 rows and 718339 columns
# Presolve time: 0.67s
# Presolved: 8760 rows, 70080 columns, 78840 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 8.760e+03
#  Factor NZ  : 1.489e+05 (roughly 30 MB of memory)
#  Factor Ops : 3.144e+06 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -3.17857904e+08 -1.80022005e+08  2.63e+05 2.22e-16  6.24e+04     1s
#    1  -3.93209674e+07 -1.19312750e+08  6.81e+04 1.81e-01  1.60e+04     1s
#    2  -2.01014915e+07 -7.91703450e+07  5.46e+04 1.45e-01  1.28e+04     1s
#    3  -5.58413185e+06 -3.97061396e+07  4.49e+04 1.25e-01  1.05e+04     1s
#    4   4.53631413e+06 -9.56676016e+06  3.81e+04 1.13e-01  9.01e+03     1s
#    5   8.81039452e+06  1.52817801e+07  3.55e+04 1.05e-01  8.37e+03     1s
#    6   1.19987887e+07  3.87056970e+07  3.37e+04 9.82e-02  7.96e+03     1s
#    7   1.97454426e+07  7.49395137e+07  2.88e+04 8.74e-02  6.82e+03     1s
#    8   2.39303495e+07  9.62437949e+07  2.63e+04 8.40e-02  6.25e+03     1s
#    9   2.67339272e+07  1.11448387e+08  2.45e+04 8.19e-02  5.88e+03     1s
#   10   2.85924177e+07  1.28179389e+08  2.34e+04 8.06e-02  5.65e+03     1s
#   11   3.04886106e+07  1.58362416e+08  2.21e+04 7.80e-02  5.36e+03     1s
#   12   3.17999003e+07  1.68283946e+08  2.14e+04 7.72e-02  5.20e+03     1s
#   13   3.30504964e+07  2.12793044e+08  2.06e+04 7.52e-02  5.02e+03     1s
#   14   3.39014562e+07  2.69821156e+08  2.00e+04 7.31e-02  4.89e+03     1s
#   15   3.49543119e+07  2.90949367e+08  1.93e+04 7.26e-02  4.74e+03     1s
#   16   3.60189052e+07  3.50469775e+08  1.87e+04 7.11e-02  4.60e+03     1s
#   17   3.62437783e+07  3.58336293e+08  1.86e+04 7.10e-02  4.58e+03     1s
#   18   3.77959371e+07  3.39869106e+08  1.79e+04 6.89e-02  4.45e+03     1s
#   19   3.80312813e+07  3.73487985e+08  1.78e+04 6.76e-02  4.35e+03     1s
#   20   3.98403200e+07  4.21390053e+08  1.69e+04 6.56e-02  4.18e+03     1s
#
# Barrier performed 20 iterations in 1.11 seconds (1.35 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     8785    9.1316543e+07   0.000000e+00   0.000000e+00      2s
#
# Solved in 8785 iterations and 1.62 seconds (2.27 work units)
# Optimal objective  9.131654345e+07
# INFO:pypsa.linopf:Optimization successful. Objective value: 9.13e+07
# ('ok', 'optimal')

# %% [markdown]
# ## 1. Plot Generators

# %% [markdown]
# ### 1.1 Plot graphs (supply by sector)

# %%
# Group the generators by the type, and print their summed power outputs over the simulation period
p_by_carrier = network.generators_t.p.groupby(
    network.generators.type, axis=1).sum()
p_by_carrier
# Out:
# type                 Biomass gasification  Imports  \
# snapshot
# 2050-01-01 00:00:00            3767.12329      0.0
# 2050-01-01 01:00:00            3767.12329      0.0
# 2050-01-01 02:00:00            3767.12329      0.0
# 2050-01-01 03:00:00            3767.12329      0.0
# 2050-01-01 04:00:00            3767.12329      0.0
# ...                                   ...      ...
# 2050-12-31 19:00:00            3767.12329      0.0
# 2050-12-31 20:00:00            3767.12329      0.0
# 2050-12-31 21:00:00            3767.12329      0.0
# 2050-12-31 22:00:00            3767.12329      0.0
# 2050-12-31 23:00:00            3767.12329      0.0
#
# type                 Methane Reformation with CCUS  Networked Electrolysis  \
# snapshot
# 2050-01-01 00:00:00                   24889.910563            27055.856046
# 2050-01-01 01:00:00                   24889.910563            27092.494234
# 2050-01-01 02:00:00                   24889.910563            27132.345975
# 2050-01-01 03:00:00                   24889.910563            27198.556845
# 2050-01-01 04:00:00                   24889.910563            27159.403483
# ...                                            ...                     ...
# 2050-12-31 19:00:00                   24889.910563            26458.319362
# 2050-12-31 20:00:00                   24889.910563            26095.813851
# 2050-12-31 21:00:00                   24889.910563            24981.317121
# 2050-12-31 22:00:00                   24889.910563            23456.935103
# 2050-12-31 23:00:00                   24889.910563            23085.819468
#
# type                 Non-networked Electrolysis  Nuclear Electrolysis
# snapshot
# 2050-01-01 00:00:00                11418.055926           2283.105024
# 2050-01-01 01:00:00                12167.723676           2283.105024
# 2050-01-01 02:00:00                12382.890774           2283.105024
# 2050-01-01 03:00:00                12457.821738           2283.105024
# 2050-01-01 04:00:00                12149.554566           2283.105024
# ...                                         ...                   ...
# 2050-12-31 19:00:00                 7971.508602           2283.105024
# 2050-12-31 20:00:00                 7560.795597           2283.105024
# 2050-12-31 21:00:00                 7149.767655           2283.105024
# 2050-12-31 22:00:00                 6928.226247           2283.105024
# 2050-12-31 23:00:00                 7035.892791           2283.105024
#
# [8760 rows x 6 columns]

# %%
p_by_carrier.values.sum() / 1e6
# Out:
# 429.7136132967382

# %%
p_by_carrier['Methane Reformation with CCUS'].values.sum() / 1e6
# Out:
# 218.0356165318801

# %%
p_by_carrier['Networked Electrolysis'].values.sum() / 1e6
# Out:
# 119.63204546377399

# %%
p_by_carrier['Non-networked Electrolysis'].values.sum() / 1e6
# Out:
# 39.045951270444014

# %%
p_by_carrier['Biomass gasification'].values.sum() / 1e6
# Out:
# 33.00000002040001

# %%
p_by_carrier['Nuclear Electrolysis'].values.sum() / 1e6
# Out:
# 20.00000001024

# %%
p_by_carrier['Imports'].values.sum() / 1e6
# Out:
# 0.0

# %%
# p_by_carrier.to_csv('1c-output\p_supply-by-sector.csv', index=True)

# %% [markdown]
# ### 1.2 Plot graphs

# %%
import matplotlib.patches as mpatches

# %%
# Graph hydrogen output of the different generation types
cols = ['Imports','Methane Reformation with CCUS', 'Biomass gasification', 'Nuclear Electrolysis', 'Networked Electrolysis',
        'Non-networked Electrolysis']

plt.rcParams.update({'font.size': 12})

p_by_carrier = p_by_carrier[cols]

colors = {'Methane Reformation with CCUS': '#444e86',
          'Biomass gasification': '#955196',
          'Nuclear Electrolysis': '#dd5182',
          'Networked Electrolysis': '#ff6e54',
          'Non-networked Electrolysis': '#FFD700',
          'Imports': '#003f5c'}

fig, ax = plt.subplots(1, 1)
fig.set_size_inches(10,7)
(p_by_carrier / 1e3).plot(
    kind="area", ax=ax, linewidth=0,
    color=[colors[col] for col in p_by_carrier.columns])

# Put a legend below current axis
ax.legend(loc='upper left', prop={'size': 11}, bbox_to_anchor=(-0.01, -0.1),
          fancybox=True, shadow=True, ncol=3, handletextpad=0.3, columnspacing=1.5)

ax.set_ylabel("Supply by Sector, GW", labelpad=10)

ax.set_xlabel("")
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# ## 2. Plot Demand

# %% [markdown]
# ### 2.1 Plot graphs (demand by cluster)

# %%
# Print loads by their hydrogen consumption over the simulation period
p_by_cluster = network.loads_t.p
p_by_cluster
# Out:
# Load                   St Fergus  Grangemouth     Teesside   Humberside  \
# snapshot
# 2050-01-01 00:00:00  2728.972199  4912.801496  4642.701219  8371.578061
# 2050-01-01 01:00:00  2749.498747  4960.696775  4701.426293  8432.150442
# 2050-01-01 02:00:00  2786.578619  5047.216475  4807.509314  8541.570500
# 2050-01-01 03:00:00  2873.683545  5250.461302  5056.710654  8798.610930
# 2050-01-01 04:00:00  3051.598116  5665.595302  5565.712288  9323.624154
# ...                          ...          ...          ...          ...
# 2050-12-31 19:00:00  3138.364478  5898.210780  5829.683995  9691.818691
# 2050-12-31 20:00:00  3100.955542  5810.923261  5722.659540  9581.427584
# 2050-12-31 21:00:00  2997.903857  5570.469331  5427.835596  9277.329407
# 2050-12-31 22:00:00  2853.684904  5233.958438  5015.234861  8851.749550
# 2050-12-31 23:00:00  2699.332044  4873.801766  4573.641702  8396.265260
#
# Load                 Theddlethorpe   Merseyside  Barrow       Bacton  \
# snapshot
# 2050-01-01 00:00:00    3132.730482  6755.349096     0.0  4130.813177
# 2050-01-01 01:00:00    3213.071110  6902.903559     0.0  4178.993355
# 2050-01-01 02:00:00    3358.201218  7169.451079     0.0  4266.027706
# 2050-01-01 03:00:00    3699.128704  7795.602174     0.0  4470.481510
# 2050-01-01 04:00:00    4395.483898  9074.535625     0.0  4888.084882
# ...                            ...          ...     ...          ...
# 2050-12-31 19:00:00    4731.041641  9709.459166     0.0  5089.318457
# 2050-12-31 20:00:00    4584.623575  9440.546169     0.0  5001.511719
# 2050-12-31 21:00:00    4181.280695  8699.762291     0.0  4759.627479
# 2050-12-31 22:00:00    3616.809688  7663.048756     0.0  4421.114895
# 2050-12-31 23:00:00    3012.674712  6553.487950     0.0  4058.815876
#
# Load                   Grain LNG  Southampton  South Wales
# snapshot
# 2050-01-01 00:00:00  4030.420696  2130.375036  3582.736039
# 2050-01-01 01:00:00  4124.835922  2182.054675  3664.566123
# 2050-01-01 02:00:00  4295.390877  2275.410575  3812.386838
# 2050-01-01 03:00:00  4696.044281  2494.714430  4159.634869
# 2050-01-01 04:00:00  5514.391555  2942.649504  4868.899977
# ...                          ...          ...          ...
# 2050-12-31 19:00:00  5908.734509  3158.499236  5210.752446
# 2050-12-31 20:00:00  5736.665964  3064.314849  5061.619897
# 2050-12-31 21:00:00  5262.662827  2804.861880  4650.799336
# 2050-12-31 22:00:00  4599.304078  2441.762180  4075.863450
# 2050-12-31 23:00:00  3889.332767  2053.148369  3460.528255
#
# [8760 rows x 11 columns]

# %%
p_by_cluster.values.sum() / 1e6
# Out:
# 429.7136132969

# %%
# p_by_cluster.to_csv('1c-output\p_demand-by-cluster.csv', index=True)

# %%
# Graph the hydrogen demand by clusters
cols = ['St Fergus', 'Grangemouth','Teesside', 'Humberside', 'Theddlethorpe', 'Merseyside', 
        'Barrow', 'Bacton', 'Grain LNG', 'Southampton', 'South Wales']

plt.rcParams.update({'font.size': 12})

p_by_cluster = p_by_cluster[cols]

colors = {'St Fergus': '#BD959D',
          'Grangemouth': '#94214B',
          'Teesside': '#9E0F1E',
          'Humberside': '#AD382B',
          'Theddlethorpe': '#63141C',
          'Merseyside': '#463A49',
          'Barrow': 'pink',
          'Bacton': '#096377',
          'Grain LNG': '#5B7436',
          'Southampton': '#D4AF37',
          'South Wales': '#FFEF00'}

fig, ax = plt.subplots(1, 1)
fig.set_size_inches(10,7)
(p_by_cluster / 1e3).plot(
    kind="area", ax=ax, linewidth=0,
    color=[colors[col] for col in p_by_cluster.columns])

# Put a legend below current axis
ax.legend(loc='upper left', prop={'size': 11}, bbox_to_anchor=(0, -0.1),
          fancybox=True, shadow=True, ncol=5, handletextpad=0.3, columnspacing=1.5)

ax.set_ylabel("Demand by Cluster, GW", labelpad=10)

ax.set_xlabel("")
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# ### 2.2 Plot graphs (demand by sector)

# %%
# read demand by sector folder:
path = '1c-LOPF\demand_input'

# %%
# heating
df_heating = pd.read_csv(path+'\h2-heating.csv')
df_heating = df_heating.set_index(['name'])
df_heating['Heating (Residential + Commercial)']=df_heating.iloc[:, 0:10].sum(axis=1)
df_heating = df_heating.filter(['Heating (Residential + Commercial)'], axis=1)

# industy
df_industry = pd.read_csv(path+'\h2-industrial.csv')
df_industry = df_industry.set_index(['name'])
df_industry['Industry']=df_industry.iloc[:, 0:10].sum(axis=1)
df_industry = df_industry.filter(['Industry'], axis=1)

# power generation
df_power = pd.read_csv(path+'\h2-power.csv')
df_power = df_power.set_index(['name'])
df_power['Power Generation']=df_power.iloc[:, 0:10].sum(axis=1)
df_power = df_power.filter(['Power Generation'], axis=1)

# road transport
df_transport = pd.read_csv(path+'\h2-transport.csv')
df_transport = df_transport.set_index(['name'])
df_transport['Road Transport']=df_transport.iloc[:, 0:10].sum(axis=1)
df_transport = df_transport.filter(['Road Transport'], axis=1)

# shipping and aviation (synthetic fuels)
df_fuels = pd.read_csv(path+'\h2-synthetic-fuels.csv')
df_fuels = df_fuels.set_index(['name'])
df_fuels['Synthetic Fuels']=df_fuels.iloc[:, 0:10].sum(axis=1)
df_fuels = df_fuels.filter(['Synthetic Fuels'], axis=1)

# exports
df_exports = pd.read_csv(path+'\h2-daccs.csv')
df_exports = df_exports.set_index(['name'])
df_exports['DACCS']=df_exports.iloc[:, 0:10].sum(axis=1)
df_exports = df_exports.filter(['DACCS'], axis=1)


df_demand = pd.concat([df_heating, df_industry, df_power, df_transport, df_fuels, df_exports], ignore_index=False, axis=1)

# %%
# Graph the hydrogen demand by sectors
cols = ['DACCS','Road Transport','Synthetic Fuels','Industry','Heating (Residential + Commercial)','Power Generation']

plt.rcParams.update({'font.size': 12})

df_demand = df_demand[cols]

df_demand.index = pd.to_datetime(df_demand.index)

colors = {'Heating (Residential + Commercial)': '#00B198',
          'Industry': '#009DAE',
          'Power Generation': '#00FC82',
          'Road Transport': '#004394',
          'Synthetic Fuels': '#006EA5',
          'DACCS': '#1A266D'}

fig, ax = plt.subplots()    
fig.set_size_inches(10,7)
(df_demand / 1e3).plot(
    kind="area", ax=ax, linewidth=0,
    color=[colors[col] for col in df_demand.columns])

ax.margins(x=0)

# Put a legend below current axis
ax.legend(loc='upper left', prop={'size': 11}, bbox_to_anchor=(0.07, -0.1),
          fancybox=True, shadow=True, ncol=3, handletextpad=0.3, columnspacing=1.5)

ax.set_ylabel("Demand by Sector, GW", labelpad=10)

ax.set_xlabel("")
# Out:
# Text(0.5, 0, '')

# %%
# df_demand.to_csv('1c-output\p_demand-by-sector.csv', index=True)

# %% [markdown]
# ## 3. Plot Storage

# %%
# Group the storage, and print their summed state of charge over the simulation period
p_storage = network.storage_units_t.p.sum(axis=1)
state_of_charge = network.storage_units_t.state_of_charge.sum(axis=1)
state_of_charge
# Out:
# snapshot
# 2050-01-01 00:00:00    2.497229e+07
# 2050-01-01 01:00:00    2.499738e+07
# 2050-01-01 02:00:00    2.502147e+07
# 2050-01-01 03:00:00    2.504277e+07
# 2050-01-01 04:00:00    2.505773e+07
#                            ...
# 2050-12-31 19:00:00    2.490032e+07
# 2050-12-31 20:00:00    2.490781e+07
# 2050-12-31 21:00:00    2.491725e+07
# 2050-12-31 22:00:00    2.492980e+07
# 2050-12-31 23:00:00    2.494729e+07
# Length: 8760, dtype: float64

# %%
# state_of_charge.to_csv('1c-output\p_storage.csv', index=True)

# %%
# Graph the storage state of charge and dispatch over the simulation period
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(15,10)

state_of_charge.plot(label="Salt cavern state of charge", ax=ax, linewidth=3)

ax.legend(prop={'size': 15})
ax.grid()
ax.set_ylabel("MWh")
ax.set_xlabel("")
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# ## 4. Plot Line Loading

# %% [markdown]
# ### 4.1 Mean Loads

# %%
# Get mean generator capacity by bus and carrier:

load = network.loads.assign(g=network.loads_t.p.mean()).groupby(["bus"]).g.sum()
flow = pd.Series(10, index=network.branches().index)
load
# Out:
# bus
# Bacton            4268.844910
# Barrow               0.000000
# Grain LNG         4171.695339
# Grangemouth       5515.904808
# Humberside       10781.732303
# Merseyside        7272.831216
# South Wales       3820.997061
# Southampton       2292.800867
# St Fergus         2766.793150
# Teesside          4970.130974
# Theddlethorpe     3192.334817
# Name: g, dtype: float64

# %%
# Plot graph:

plt.rcParams.update({'font.size': 12})

plt.rc('figure', figsize=(15,10))

collection = network.plot(
    bus_sizes=load / 1e5,
    bus_colors='green',
    margin=0.3,
    flow=flow,
    link_widths=1.7,
    projection=ccrs.EqualEarth(),
    color_geomap=True,
    link_colors=network.links_t.p0.mean().abs() / 1e3)

cbar=plt.colorbar(collection[2], fraction=0.04, pad=0.004, location='left')

cbar.set_label('Mean Flow, GW', labelpad=10, loc='center', rotation=90)

plt.show()
# Out:
# c:\Users\ls1524\AppData\Local\miniconda3\envs\PyPSA-GB\lib\site-packages\cartopy\mpl\style.py:76: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %% [markdown]
# ### 4.2 Peak Loads

# %%
# Get mean generator capacity by bus and carrier:

load = network.loads.assign(g=network.loads_t.p.max()).groupby(["bus"]).g.sum()
flow = pd.Series(10, index=network.branches().index)
load
# Out:
# bus
# Bacton            8355.125337
# Barrow               0.000000
# Grain LNG        10677.906450
# Grangemouth       8245.619981
# Humberside       18442.500318
# Merseyside       16627.317894
# South Wales      10737.124352
# Southampton       6737.883804
# St Fergus         5945.912917
# Teesside          7931.933833
# Theddlethorpe     8172.079706
# Name: g, dtype: float64

# %%
# Plot graph:

plt.rcParams.update({'font.size': 12})

plt.rc('figure', figsize=(15,10))

collection = network.plot(
    bus_sizes=load / 1e5,
    bus_colors='#9E0F1E',
    margin=0.3,
    flow=flow,
    link_widths=1.7,
    projection=ccrs.EqualEarth(),
    color_geomap=True,
    link_colors=network.links_t.p0.max().abs() / 1e3)

cbar=plt.colorbar(collection[2], fraction=0.04, pad=0.004, location='left')

cbar.set_label('Peak Flow, GW', labelpad=10, loc='center', rotation=90)

plt.show()

# %%
# network.links_t.p0.mean().abs().to_csv('1c-output\p_links_mean.csv', index=True)

# %%
# network.links_t.p0.max().abs().to_csv('1c-output\p_links_max.csv', index=True)

# %%
# network.links_t.p0.min().abs().to_csv('1c-output\p_links_min.csv', index=True)
